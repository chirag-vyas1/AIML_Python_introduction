# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **`KN NOTES`**

# %% [markdown]
# ## **`1. What are Dictionaries?`**
#
# - Dictionary is a collection of key-value pairs.
# - Dictionaries are also known as maps or associative arrays.
# - A dictionary contains comma separated `key : value` pairs enclosed within `{}`.
#
# ```python
# d1 = {}    # empty dictionary
# d2 = {'A101': 'Amol', 'A102': 'Anil', 'B103': 'Ravi'}
# # herer 'A101','A102' are keys, whereas , 'Amol','Anil','Ravi are values
#
# ```
# - Different keys may have same values.
#
# ```python
# d = {10: 'A', 20: 'A', 30: 'Z'}    # ok
#
# ```
# - Keys must be unique. If keys are same, but values are different, latest key-value pair gets stored.
#
# ```python
# d = {10: 'A', 20: 'B', 10: 'Z'}    # will store {10: 'Z', 20: 'B'}
# ```
# - If key-value pairs are repeated, then only one pair gets stored.
# ```python
# d = {10: 'A', 20: 'B', 10: 'A'}    # will store {10: 'A', 20: 'B'}
# ```

# %% [markdown]
# ## **`2.Accessing Dictionary Elements`**
# - Entire dictionary can be printed by just using the name of the dictionary.
# ```python
# d = {'A101': 'Amol', 'A102': 'Anil', 'B103': 'Ravi'}
# print(d)
# ```
# - Unlike sets, dictionaries preserve insertion order. However, elements are not accessed using the position, but using the key.
#   Thus, elements are not position indexed, but key indexed.
# ```python
# d = {'A101': 'Dinesh', 'A102': 'Shrikant', 'B103': 'Sudhir'}
# print(d['A102'])    # prints value for key 'A102'
#
# ```
#
# - Dictionaries cannot be sliced using `[]`.

# %% [markdown]
# ## **`3.Looping in Dictionaries`**
#
# Like strings, lists, tuples and sets, dictionaries too can be iterated over using a for loop. There are three ways to do so:
#
# ```python
# courses = {'DAA': 'CS', 'AOA': 'ME', 'SVY': 'CE'}
#
# # iterate over key-value pairs
# for k, v in courses.items():
#     print(k, v)
#
# # iterate over keys
# for k in courses.keys():
#     print(k)
#
# # iterate over keys - shorter way
# for k in courses:
#     print(k)
#
# # iterate over values
# for v in courses.values():
#     print(v)

# %% [markdown]
# - While iterating through a dictionary using a for loop, if we wish to keep track of index of the key-value pairs that is being referred to, we can do so using the built-in enumerate() function.
#
# ```python
# courses = {'DAA': 'CS', 'AOA': 'ME', 'SVY': 'CE'}
# for i, (k, v) in enumerate(courses.items()):
#     print(i, k)
# ```
# - Note that() around **k**,**v** are necessary.

# %% [markdown]
# ## **`4. Basic Dictionary Operations`**
# - Dictionaries are mutable. So, we can perform add/delete/modify operations on a dictionary.
#
# ```python
# courses = {
#     'CS101': 'CPP',
#     'CS102': 'DS',
#     'CS201': 'OOP',
#     'CS226': 'DAA',
#     'CS601': 'Crypt',
#     'CS442': 'Web'
# }
#
# # add, modify, delete
# courses['CS444'] = 'Web Services'  # add new key-
# courses['CS201'] = 'OOP Using Java'    # modify value for a key
# del(courses['CS102'])                  # delete a key-value pair
# del(courses)                           # delete dictionary object
# ```
# - Note that any new addition will take place at the end of the existing dictionary, since dictionary preserves the insertion order.
# - **popitem()** Dictionary keys cannot be changed in place.
# - **Given below are the operations that work on list and tuples. These operations are discussed in detail in chapter 8.Try these operations on dictionaries as an exercises**
# ```
# Concatenation - doesn't work
# Merging - doesn't work
# Conversion - works
# Aliasing - works
# Cloning - works
# Searching - works
# Identity - works
# Comparison - doesn't work
# Emptiness - works
# ```
# - Two dictionaries cannot be concatenated using +.
# - Two dictionaries cannot be merged using the form z = s + t.
# - Two dictionary objects cannot be compared using <, >.value pair

# %% [markdown]
# ## **`5. Using Built-in Functions on Dictionaries`**
# - Many built-in functions can be used with dictionaries:
#
# ```python
# d = {'CS101': 'CPP', 'CS102': 'DS', 'CS201': 'OOP'}
# len(d)         # returns number of key-value pairs
# max(d)         # returns maximum key
# min(d)         # returns minimum key
# sorted(d)      # returns sorted list of keys
# sum(d)         # returns sum of all keys (if keys are numbers)
# any(d)         # returns True if any key is True
# all(d)         # returns True if all keys are True
# reversed(d)    # can be used for reversing dict/key
# ```
# - Example of reversed() function by keys is shown:
#
# ```python
# courses = {'CS101': 'CPP', 'CS102': 'DS', 'CS201': 'OOP'}
# for k, v in reversed(courses.items()):
#     print(k, v)s/values

# %% [markdown]
# ## **`6. Dictionary Methods`**
#
# - There are many dictionary methods. Many of the operations performed by them can also be performed using built-in functions. The useful dictionary methods are shown below:
#
# ```python
# c = {'CS101': 'CPP', 'CS102': 'DS', 'CS201': 'OOP'}
# d = {'ME126': 'HPE', 'ME102': 'TOM', 'ME234': 'AEM'}
#
# print(c.get('CS102', 'Absent'))    # prints DS
# print(c.get('EE102', 'Absent'))    # prints Absent
# print(c['EE102'])                  # raises KeyError
#
# c.update(d)                        # updates c with items in d
# print(c.popitem())                 # removes and returns item in LIFO order
# print(c.pop('CS102'))              # removes key and returns its value
# c.clear()                          # clears all dictionary entries
# ```
# - Note that while updating a dictionary if keys are same, values are overwritten.
# - `popitem()` is useful in destructively iterating through a dictionary.v)

# %% [markdown]
# ## **`7. Dictionary Varieties`**
# - Keys in a dictionary must be unique and immutable. Numbers, strings or tuples can be used as keys. If tuple is used as a key, it should not contain any mutable element like list.
# ```python
# d = {(1, 5): 'ME126', (3, 2): 'ME102', (5, 4): 'ME234'}  # Corrected: using tuples instead of sets
# ```
# - Dictionaries can be nested.
# ```python
# contacts = {
#     'Anil': {'DOB': '17/11/98', 'Favorite': 'Igloo'},
#     'Amol': {'DOB': '14/10/99', 'Favorite': 'Tundra'},
#     'Ravi': {'DOB': '19/11/97', 'Favorite': 'Arctic'}
# }
# ```
# - Two dictionaries can be merged to create a third dictionary by unpacking the two dictionaries using **. If we use * only keys will be unpacked.
# ```python
# animals = {'Tiger': 141, 'Lion': 152, 'Leopard': 110}
# birds = {'Eagle': 38, 'Crow': 3, 'Parrot': 2}
# combined = {**animals, **birds}
#
#
# ```
# - A dictionary with different keys but same values can be created using fromkeys():
# ```python
# lst = [12, 13, 14, 15, 16]
# d = dict.fromkeys(lst, 25) # keys - list items, all values set to 25

# %% [markdown]
# ## **`Problem 11.1`** - Dictionary Copy Operations
# **Problem Statement
# Create a dictionary called students containing names and ages. Copy the dictionary into **stud**. Empty the **students** dictionary, as **stud** continues to hold the data.**
# ## **`Program`**

# %%
students = {'Ani!': 23, 'Sanjay': 28, 'Ajay': 25}
stud = students  # shallow copy, stud starts referring to same dictionary
students = {}    # students now refers to an empty dictionary
print(stud)
# Out:
# {'Ani!': 23, 'Sanjay': 28, 'Ajay': 25}

# %% [markdown]
# ## **`Tips`**
# - By making a shallow copy, a new dictionary is not created. stud just starts referring (pointing) to the same data to which students was referring (pointing).
# - Had we used students.clear() it would have cleared all the data, so students and stud both would have referred to an empty dictionary.

# %% [markdown]
# ## **`Problem 11.2 - Dictionary from List`**
# **Problem Statement
# Create a list of cricketers. Use this list to create a dictionary in which the list values become keys of the dictionary. Set the values of all keys to 50 in the dictionary created.**
#
# ### **`Program`**

# %%
list = ['Sunil', 'Sachin', 'Rahul', 'Kapil', 'Sunil', 'Rahul']
d = dict.fromkeys(list, 50)
print(len(list))
print(len(d))
print(d)
# Out:
# 6
# 4
# {'Sunil': 50, 'Sachin': 50, 'Rahul': 50, 'Kapil': 50}

# %% [markdown]
# ## **`Tips`**
# -
# The list may contain duplicate items, whereas a dictionary always contains unique keys. Hence when the dictionary is created from list, duplicates are eliminated, as seen in the output.

# %% [markdown]
# ## **`Problem 11.3 - Dictionary Sorting`**
# **Problem Statement
# Write a program to sort a dictionary in ascending/descending order by key and ascending/descending order by value.**
# ## **`Program`**

# %%
import operator

d = {'Oil': 230, 'Clip': 150, 'Stud': 175, 'Nut': 35}
print('Original dictionary: ', d)

# sorting by key
d1 = sorted(d.items())
print('Asc. order by key: ', d1)
d2 = sorted(d.items(), reverse = True)
print('Des. order by key: ', d2)

# sorting by value
d1 = sorted(d.items(), key = operator.itemgetter(1))
print('Asc. order by value: ', d1)
d2 = sorted(d.items(), key = operator.itemgetter(1), reverse = True)
print('Des. order by value: ', d2)
# Out:
# Original dictionary:  {'Oil': 230, 'Clip': 150, 'Stud': 175, 'Nut': 35}
# Asc. order by key:  [('Clip', 150), ('Nut', 35), ('Oil', 230), ('Stud', 175)]
# Des. order by key:  [('Stud', 175), ('Oil', 230), ('Nut', 35), ('Clip', 150)]
# Asc. order by value:  [('Nut', 35), ('Clip', 150), ('Stud', 175), ('Oil', 230)]
# Des. order by value:  [('Oil', 230), ('Stud', 175), ('Clip', 150), ('Nut', 35)]

# %% [markdown]
# ## **`Tips`**
# - By default, items in a dictionary would be sorted as per the key.
# - To sort by values we need to use **operator.itemgetter(1).**
# - The key parameter of **sorted()** requires a key function (to be able to compare objects to be sorted) rather than a single key value.
# - **operator.itemgetter(1)** gives a function that grabs the first element from a list-like object.
# - In general, **operator.itemgetter(n)** constructs a callable that assumes an iterable as input and fetches the n-th element out of it.

# %% [markdown]
# ## **`Problem 11.4 - Dictionary Concatenation`**
# **Problem Statement
# Write a program to create three dictionaries and concatenate them to create a fourth dictionary.**
#
# ## **`Program`**

# %%
# Method 1: Using update() in a loop
d1 = {'Mango': 30, 'Guava': 20}
d2 = {'Apple': 70, 'Pineapple': 50}
d3 = {'Kiwi': 90, 'Banana': 35}
d4 = {}
for d in (d1, d2, d3):
    d4.update(d)
print(d4)

# Method 2: Using dictionary unpacking
d5 = {**d1, **d2, **d3}
print(d5)

# Will unpack only the keys into the list
d6 = list({*d1, *d2, *d3})
print(d6)
# Out:
# {'Mango': 30, 'Guava': 20, 'Apple': 70, 'Pineapple': 50, 'Kiwi': 90, 'Banana': 35}
# {'Mango': 30, 'Guava': 20, 'Apple': 70, 'Pineapple': 50, 'Kiwi': 90, 'Banana': 35}
# ['Banana', 'Mango', 'Kiwi', 'Apple', 'Pineapple', 'Guava']

# %% [markdown]
# ## **`Tips`**
# - From the output it can be observed that the dictionaries are merged in the order listed in the expression.
# - Note that list of keys is constructed from a dictionary they are not stored in the order listed in the expression.

# %% [markdown]
# ## **`Problem 11.5 - Check Empty Dictionary`**
# Problem Statement
# Write a program to check whether a dictionary is empty or not.
#
# ## **`Program`**

# %%
d1 = {'Anil': 45, 'Amol': 32}
if bool(d1):
    print('Dictionary is not empty')
    
d2 = {}
if not bool(d2):
    print('Dictionary is empty')
# Out:
# Dictionary is not empty
# Dictionary is empty

# %% [markdown]
# ## **`Problem 11.6 - Merge Two Dictionaries`**
# **Problem Statement
# Suppose there are two dictionaries called boys and girls containing names as keys and ages as values. Write a program to merge the two dictionaries into a third dictionary.**
# ## **`Program`**

# %%
boys = {'Nilesh': 41, 'Soumitra': 42, 'Nadeem': 47}
girls = {'Rasika': 38, 'Rajashree': 43, 'Rasika': 45}

combined = {**boys, **girls}
print(combined)

combined = {**girls, **boys}
print(combined)
# Out:
# {'Nilesh': 41, 'Soumitra': 42, 'Nadeem': 47, 'Rasika': 45, 'Rajashree': 43}
# {'Rasika': 45, 'Rajashree': 43, 'Nilesh': 41, 'Soumitra': 42, 'Nadeem': 47}

# %% [markdown]
# ## **`Tips`**
# - From the output it can be observed that the dictionarie are merged in the order listed in the expression.
# - As the merging takes place, duplicates get overwritten from left to right.so Rasika:38 got overwritten with Rasika:45

# %% [markdown]
# ## **`Problem 11.7 - Find Maximum and Minimum Salary`**
# **Problem Statement
# For the given dictionary, write a program to report the maximum and minimum salary.**
# ## **`Program`**

# %%
d = {
    'anuj': {'salary': 10000, 'age': 20, 'height': 6},
    'aditya': {'salary': 6000, 'age': 26, 'height': 5.6},
    'rahul': {'salary': 7000, 'age': 26, 'height': 5.9}
}

lst = []
for v in d.values():
    lst.append(v['salary'])
    
print(max(lst))
print(min(lst))
# Out:
# 10000
# 6000

# %% [markdown]
# ## **`Problem 11.8 - Student Congratulations Message`**
# Problem Statement
# Suppose a dictionary contains roll numbers and names of students. Write a program to receive the roll number, extract the name corresponding to the roll number and display a message congratulating the student by his name. If the roll number doesn't exist in the dictionary, the message should be 'Congratulations Student!'.
#
# ## **`Program`**

# %%
students = {554: 'Ajay', 350: 'Ramesh', 395: 'Rakesh'}

rollno = int(input('Enter roll number: '))
name = students.get(rollno, 'Student')
print(f'Congratulations {name}!')

rollno = int(input('Enter roll number: '))
name = students.get(rollno, 'Student')
print(f'Congratulations {name}!')
# Out:
# Enter roll number:  4
# Congratulations Student!
# Enter roll number:  4
# Congratulations Student!

# %% [markdown]
# # **`EXERCISES`**

# %% [markdown]
# ## **`[A] Dictionary Concepts - True or False`**
#
# ## Questions and Answers
#
# | Statement | Answer | Explanation |
# |-----------|--------|-------------|
# | (a) Dictionary elements can be accessed using position-based index. | **False** | Dictionary elements are accessed by keys, not by position |
# | (b) Dictionaries are immutable. | **False** | Dictionaries are mutable - you can add, remove, and modify key-value pairs |
# | (c) Insertion order is preserved by a dictionary. | **True** | Since Python 3.7, dictionaries maintain insertion order |
# | (d) The very first key-value pair in a dictionary d can be accessed using the expression d[0]. | **False** | `d[0]` looks for key `0`, not the first inserted item |
# | (e) courses.clear() will delete the dictionary object called courses. | **False** | `clear()` empties the dictionary but the object still exists |
# | (f) It is possible to nest dictionaries. | **True** | Dictionaries can contain other dictionaries as values |
# | (g) It is possible to hold multiple values against a key in a dictionary. | **True** | A key can have a list, tuple, or set as its value to store multiple items |

# %% [markdown]
# ## **`[B] Dictionary Programming Questions - Exact Questions`**

# %% [markdown]
# **(a) Write a program that reads a string from the keyboard and creates dictionary containing frequency of each character occurring in the string. Also print these occurrences in the form of a histogram.**

# %%
# Read string from keyboard
text = input("Enter a string: ")

# Create frequency dictionary
freq_dict = {}
for char in text:
    freq_dict[char] = freq_dict.get(char, 0) + 1

print("Character frequencies:", freq_dict)

# Print histogram
print("\nHistogram:")
for char, count in freq_dict.items():
    print(f"{char}: {'*' * count}")
# Out:
# Enter a string:  chirag
# Character frequencies: {'c': 1, 'h': 1, 'i': 1, 'r': 1, 'a': 1, 'g': 1}
#
# Histogram:
# c: *
# h: *
# i: *
# r: *
# a: *
# g: *

# %% [markdown]
# **(b) Create a dictionary containing names of students and marks obtained by them in three subjects. Write a program to replace the marks in three subjects with the total in three subjects, and average marks. Also report the topper of the class.**

# %%
# Student marks dictionary
students = {
    'Rahul': [85, 90, 78],
    'Priya': [92, 88, 95],
    'Amit': [76, 82, 80],
    'Sneha': [95, 96, 94]
}

topper = ''
highest_total = 0

# Process each student
for name, marks in students.items():
    total = sum(marks)
    average = total / 3
    # Replace marks with total and average
    students[name] = {'total': total, 'average': round(average, 2)}
    
    # Find topper
    if total > highest_total:
        highest_total = total
        topper = name

print("Student Results:")
for name, data in students.items():
    print(f"{name}: Total = {data['total']}, Average = {data['average']}")

print(f"\nClass Topper: {topper} with total marks {highest_total}")
# Out:
# Student Results:
# Rahul: Total = 253, Average = 84.33
# Priya: Total = 275, Average = 91.67
# Amit: Total = 238, Average = 79.33
# Sneha: Total = 285, Average = 95.0
#
# Class Topper: Sneha with total marks 285

# %% [markdown]
# **(c) Given the following dictionary:**
# ```python
# portfolio = {
#     'accounts': ['SBI', 'IOBI],
#     'shares': ' [HDFC, 'ICICI', 'TM', 'TCS],
#     'ornaments': ['10 gm gold', '1 kg silver']
#     }
# ```
# **Write a program to perform the following operations:**
# - Add a key to portfolio called 'MF' with values 'Reliance' and 'ABSU'.
# - Set the value of 'accounts' to a list containing 'Axis' and 'BOB'.
# - Sort the items in the list stored under the 'shares' key.
# - Delete the list stored under 'ornaments' key.

# %%
portfolio = {
    'accounts': ['SBI', 'IOB'],
    'shares': ['HDFC', 'ICICI', 'TM', 'TCS'],
    'ornaments': ['10 gm gold', '1 kg silver']
}

print("Original portfolio:", portfolio)

# Add new key 'MF'
portfolio['MF'] = ['Reliance', 'ABSL']

# Update 'accounts' key
portfolio['accounts'] = ['Axis', 'BOB']

# Sort 'shares' list
portfolio['shares'].sort()

# Delete 'ornaments' key
del portfolio['ornaments']

print("Updated portfolio:", portfolio)
# Out:
# Original portfolio: {'accounts': ['SBI', 'IOB'], 'shares': ['HDFC', 'ICICI', 'TM', 'TCS'], 'ornaments': ['10 gm gold', '1 kg silver']}
# Updated portfolio: {'accounts': ['Axis', 'BOB'], 'shares': ['HDFC', 'ICICI', 'TCS', 'TM'], 'MF': ['Reliance', 'ABSL']}

# %% [markdown]
# **(d) Create two dictionaries—one containing grocery items and their prices and another containing grocery items and quantity purchased. By using the values from these two dictionaries compute the total bill.**

# %%
# Price dictionary
prices = {
    'Rice': 50,
    'Wheat': 30,
    'Sugar': 40,
    'Salt': 20,
    'Oil': 120
}

# Quantity dictionary
quantities = {
    'Rice': 2,
    'Wheat': 3,
    'Sugar': 1,
    'Salt': 1,
    'Oil': 2
}

# Calculate total bill
total = 0
print("Grocery Bill:")
print("-" * 20)

for item, price in prices.items():
    if item in quantities:
        quantity = quantities[item]
        item_total = price * quantity
        total += item_total
        print(f"{item}: ₹{price} × {quantity} = ₹{item_total}")

print("-" * 20)
print(f"Total Bill: ₹{total}")
# Out:
# Grocery Bill:
# --------------------
# Rice: ₹50 × 2 = ₹100
# Wheat: ₹30 × 3 = ₹90
# Sugar: ₹40 × 1 = ₹40
# Salt: ₹20 × 1 = ₹20
# Oil: ₹120 × 2 = ₹240
# --------------------
# Total Bill: ₹490

# %% [markdown]
# **(e) Which functions will you use to fetch all keys, all values and k value pairs from a given dictionary?**

# %%
sample_dict = {'a': 1, 'b': 2, 'c': 3}

# Get all keys
keys = sample_dict.keys()
print("Keys:", list(keys))

# Get all values  
values = sample_dict.values()
print("Values:", list(values))

# Get all key-value pairs
items = sample_dict.items()
print("Key-Value pairs:", list(items))
# Out:
# Keys: ['a', 'b', 'c']
# Values: [1, 2, 3]
# Key-Value pairs: [('a', 1), ('b', 2), ('c', 3)]

# %% [markdown]
# **(f) Create a dictionary of 10 usernames and passwords. Receive the username and password from keyboard and search for them in the dictionary. Print appropriate message on the screen based on whether a match is found or not.**

# %%
# User database
users = {
    'user1': 'pass123',
    'user2': 'abc456',
    'user3': 'xyz789',
    'user4': 'hello123',
    'user5': 'world456',
    'user6': 'test789',
    'user7': 'demo123',
    'user8': 'sample456',
    'user9': 'temp789',
    'user10': 'final123'
}

# Get credentials
username = input("Enter username: ")
password = input("Enter password: ")

# Check authentication
if username in users:
    if users[username] == password:
        print("Login successful!")
    else:
        print("Invalid password!")
else:
    print("Username not found!")
# Out:
# Enter username:  user1
# Enter password:  pass123
# Login successful!

# %% [markdown]
# **(g) Given the following dictionary:**
# ```python
# marks = {
#     'Subu': {'Maths': 88, 'Eng': 60, 'SSt': 95},
#     'Amol': {'Maths': 78, 'Eng': 68, 'SSt': 89},
#     'Raka': {'Maths': 56, 'Eng': 66, 'SSt': 77}
# }
# ```
# **Write a program to perform the following operations:**
# - Print marks obtained by Amol in English.
# - Set marks obtained by Raka in Maths to 77.
# - Sort the dictionary by name.

# %%
marks = {
    'Subu': {'Maths': 88, 'Eng': 60, 'SSt': 95},
    'Amol': {'Maths': 78, 'Eng': 68, 'SSt': 89},
    'Raka': {'Maths': 56, 'Eng': 66, 'SSt': 77}
}

# Print Amol's English marks
print("Amol's English marks:", marks['Amol']['Eng'])

# Update Raka's Maths marks
marks['Raka']['Maths'] = 77
print("Updated Raka's Maths marks to 77")

# Sort dictionary by name (key)
sorted_marks = dict(sorted(marks.items()))
print("\nSorted dictionary by name:")
for name, subjects in sorted_marks.items():
    print(f"{name}: {subjects}")
# Out:
# Amol's English marks: 68
# Updated Raka's Maths marks to 77
#
# Sorted dictionary by name:
# Amol: {'Maths': 78, 'Eng': 68, 'SSt': 89}
# Raka: {'Maths': 77, 'Eng': 66, 'SSt': 77}
# Subu: {'Maths': 88, 'Eng': 60, 'SSt': 95}

# %% [markdown]
# **(h) Create a dictionary which stores the following data:**
# ```python
# Interface  IP Address  status
# eth0       1.1.1.1     up
# eth1       2.2.2.2     up
# wlan0      3.3.3.3     down
# wlan1      4.4.4.4     up
# ```
# **Write a program to perform the following operations:**
# - Find the status of a given interface.
# - Find interface and IP of all interfaces which are up.
# - Find the total number of interfaces.
# - Add two new entries to the dictionary.

# %%
# Network interfaces dictionary
interfaces = {
    'eth0': {'ip_address': '1.1.1.1', 'status': 'up'},
    'eth1': {'ip_address': '2.2.2.2', 'status': 'up'},
    'wlan0': {'ip_address': '3.3.3.3', 'status': 'down'},
    'wlan1': {'ip_address': '4.4.4.4', 'status': 'up'}
}

# Find status of a given interface
interface_name = input("Enter interface name: ")
if interface_name in interfaces:
    print(f"Status of {interface_name}: {interfaces[interface_name]['status']}")
else:
    print("Interface not found")

# Find all interfaces that are up
print("\nInterfaces that are UP:")
for interface, details in interfaces.items():
    if details['status'] == 'up':
        print(f"{interface}: {details['ip_address']}")

# Total number of interfaces
print(f"\nTotal number of interfaces: {len(interfaces)}")

# Add two new entries
interfaces['eth2'] = {'ip_address': '5.5.5.5', 'status': 'up'}
interfaces['wlan2'] = {'ip_address': '6.6.6.6', 'status': 'down'}

print("\nAfter adding new interfaces:")
for interface, details in interfaces.items():
    print(f"{interface}: IP={details['ip_address']}, Status={details['status']}")
# Out:
# Enter interface name:  eth10
# Interface not found
#
# Interfaces that are UP:
# eth0: 1.1.1.1
# eth1: 2.2.2.2
# wlan1: 4.4.4.4
#
# Total number of interfaces: 4
#
# After adding new interfaces:
# eth0: IP=1.1.1.1, Status=up
# eth1: IP=2.2.2.2, Status=up
# wlan0: IP=3.3.3.3, Status=down
# wlan1: IP=4.4.4.4, Status=up
# eth2: IP=5.5.5.5, Status=up
# wlan2: IP=6.6.6.6, Status=down

# %% [markdown]
# **(i) Suppose a dictionary contains 5 key-value pairs of name and marks. Write a program to print them from last pair to first pair. Keep deleting every pair printed, such that the end of printing the dictionary falls empty.**

# %%
# Sample dictionary with 5 key-value pairs
student_marks = {
    'Alice': 85,
    'Bob': 92,
    'Charlie': 78,
    'Diana': 95,
    'Eve': 88
}

print("Printing and deleting from last to first:")
print("-" * 40)

# Convert to list of items for reverse iteration
items_list = list(student_marks.items())

# Print and delete from last to first
for i in range(len(items_list)-1, -1, -1):
    key, value = items_list[i]
    print(f"{key}: {value}")
    del student_marks[key]  # Delete the item

print(f"\nDictionary after deletion: {student_marks}")
print(f"Is dictionary empty? {len(student_marks) == 0}")
# Out:
# Printing and deleting from last to first:
# ----------------------------------------
# Eve: 88
# Diana: 95
# Charlie: 78
# Bob: 92
# Alice: 85
#
# Dictionary after deletion: {}
# Is dictionary empty? True

# %% [markdown]
# ## **`[c] Answer the following questions:`**

# %% [markdown]
# **(a) What will be the output of the following code snippet?**

# %%
d = {'Millk': 1, 'Soap': 2, 'Towel': 3, 'Shampoo': 4, 'Milk': 7}
print(d[0], d[1], d[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 d = {'Millk': 1, 'Soap': 2, 'Towel': 3, 'Shampoo': 4, 'Milk': 7}
# ----> 2 print(d[0], d[1], d[2])
#
# KeyError: 0

# %%
# Correct way to access:
print(d['Millk'], d['Soap'], d['Towel'])  # Output: 1 2 3
# Out:
# 1 2 3

# %% [markdown]
# **(b) Which of the following statements are CORRECT?**
# - **i. A dictionary will always contain unique keys.**
# - **ii. Each key in a dictionary may have multiple values.**
# - **iii. If same key is assigned a different value, latest value will prevail.**

# %% [markdown]
# **Answer:** All three statements are CORRECT:
#
# i. ✓ Dictionary keys must be uniqe
#
# ii. ✓ A key can have multiple values if stored in a list/tupleset
#
# iii. ✓ Latest value assignment overwrites previous ones

# %% [markdown]
# **(c) How will you create an empty list, empty tuple, empty set and empty dictionary?**

# %%
empty_list = [] or list()
empty_tuple = () or tuple()
empty_set = set()  # Note: {} creates dictionary
empty_dict = {} or dict()

# %% [markdown]
# **(d) How will you create a list, tuple, set and dictionary, each containing one element?**

# %%
single_list = [42]
single_tuple = (42,)  # Comma is required
single_set = {42}
single_dict = {'key': 'value'}

# %% [markdown]
# **(e) Given the following dictionary:**
# ```python
# d = {'d1': {'Frutiname': 'Mango', 'Season': 'Summer'}, 'd2': {'Frutiname': 'Orange', 'Season': 'Winter'}}
#
# ```
# **How will you access and print Mango and Winter?**

# %%
d = {'d1': {'Frutiname': 'Mango', 'Season': 'Summer'}, 
     'd2': {'Frutiname': 'Orange', 'Season': 'Winter'}}

print(d['d1']['Frutiname'])  # Prints: Mango
print(d['d2']['Season'])     # Prints: Winter
# Out:
# Mango
# Winter

# %% [markdown]
# **(f) In the following table check the box if a property is enjoyed by the data types mentioned in columns?**

# %% [markdown]
# | Property | str | list | tuple | set | dict |
# |----------|-----|------|-------|-----|------|
# | Object    |  ||    |  |    |
# | Collection    |    |    |    |    |    |
# | Mutable    |    |    |    |    |    |
# | Ordered    |    |    |    |    |    |
# | Indexed by position   |    |    |    |    |    |
# | Indexed by key    |    |    |    |    |    |
# | Iterable    |    |    |    |    |    |
# | Slicing allowed   |    |    |    |    |    |
# | Nesting allowed   |    |    |    |    |    |
# | Homogeneous elements |    |    |    |    |    |
# | Heterogeneous elements |    |    |    |    |    |

# %% [markdown]
# **Answers:**
#
# | Property | str | list | tuple | set | dict |
# |----------|-----|------|-------|-----|------|
# | Object | ✓ | ✓ | ✓ | ✓ | ✓ |
# | Collection | ✓ | ✓ | ✓ | ✓ | ✓ |
# | Mutable | | ✓ | | ✓ | ✓ |
# | Ordered | ✓ | ✓ | ✓ | | ✓ |
# | Indexed by position | ✓ | ✓ | ✓ | | |
# | Indexed by key | | | | | ✓ |
# | Iterable | ✓ | ✓ | ✓ | ✓ | ✓ |
# | Slicing allowed | ✓ | ✓ | ✓ | | |
# | Nesting allowed | ✓ | ✓ | ✓ | ✓ | ✓ |
# | Homogeneous elements | ✓ | | | | |
# | Heterogeneous elements | | ✓ | ✓ | ✓ | ✓ |

# %% [markdown]
# ### **`(g) What is the most common usage of the data types mentioned below?`**
# - str
# - list
# - tuple
# - set
# - dict

# %% [markdown]
# ### **`(g) Common Usage`**
#
# - **str (String):** Text processing, file handling, user input/output
# - **list (List):** Ordered collections that need modification, stacks, queues
# - **tuple (Tuple):** Fixed data, dictionary keys, function return values
# - **set (Set):** Unique elements, membership testing, mathematical operations
# - **dict (Dictionary):** Key-value storage, configuration data, JSON-like structures

# %% [markdown]
# ### =================== END OF CHAPTER 11 =============================
