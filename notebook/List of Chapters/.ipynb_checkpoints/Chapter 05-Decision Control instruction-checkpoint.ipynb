# %% [markdown]
# # **`Chapter 5: Decision Control Instruction`**

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## <a id='link2'></a> **`5. Decision Control Instruction`**
#
# - [5.1 Sequence & Decision Control Instructions](#sub1-1)
# - [5.2 Decision Control Instruction](#sub1-2)
# - [5.3 Nuances of Conditions](#sub1-3)
# - [5.4 Logical Operators](#sub1-4)
# - [5.5 Conditional Expressions](#sub1-5)
# - [5.6 all() and any()](#sub1-6)
# - [5.7 Receiving Input](#sub1-7)
# - [5.8 Pass Statement](#sub1-8)
# - [5.9 Programs](#sub1-9)
# - [5.10 Exercises](#sub1-10)

# %% [markdown]
# ## **`KN KnNotes`**
#
# ## <a id=sub1-1><a/>**`1. Sequence & Decision Control Instructions`**
#
# - So far, statements in all our programs execute sequentially—one after the other.
# - The sequence of execution of instructions in a program can be altered using:
#   1. **Decision control instruction**
#   2. **Repetition control instruction**

# %% [markdown]
# ## <a id=sub1-2><a/>**`2. Decision Control Instruction`**
#
# ### Three ways to take decisions in a program:
#
# ```python
#
# # 1. Simple 'if'
# if condition:
#     statement1
#     statemen
#
# # 2. 'if-else
# if condition:
#   statement1
#   statement2
#  else:
#     statement3
#     statement4
#
#
# # 3. 'if-elif-else'
# ```python
# if condition1:
#     statement1
# elif condition2:
#     statement2
# elif condition3:
#     statement3
# else:
#     statement4
# ```
# - The colon (:) after if, else, and elif is mandatory.
#
# - Statements in if, else, and elif blocks must be indented. Indented statements form a block.
#
# - Use consistent indentation (either 4 spaces or a tab); don’t mix tabs and spaces.
#
# - In the first form, else and elif are optional.
#
# - In the second form, if the condition is True, all statements in the if block execute; if False, the statements in the else block execute.
#
# - In the third form, if the initial if condition fails, the following elif conditions are checked. The else block runs only if all conditions fail.
#
# - `if-else` statements can be **nested**—as deep as your program logic demands.

# %% [markdown]
# ## <a id=sub1-3><a/>**`3. Nuances of Conditions`**
#
# - Conditions are built using **relational operators**: `<`, `>`, `<=`, `>=`, `==`, `!=`
#   - `10 < 20`  → yields `True`
#   - `'Santosh' < 'Adi'`  → yields `False`, since alphabetical order is considered
#   - `'gang' < 'God'`  → yields `False`, as lowercase letters are greater than uppercase
#
#
# - a = b` is **assignment**, `a == b` is **comparison**
#
# - **Chained comparisons** and multi-equality checks:
#
#   ```python
#   if a < b < c:
#       # checks whether b falls between a and c
#
#   if a == b == c:
#       # checks whether all three are equal
#
#   if 10 != 20 != 10:
#     # evaluates to True, because (10 != 20) is True, and (20 != 10) is True   ```
# - **In Boolean context:** Any non-zero number (positive, negative, integer, float) is treated as True and 0 as False
#
# ```python
# print(bool(3.14))   # prints True
# print(bool(25))     # prints True
# print(bool(0))      # prints False

# %% [markdown]
# ## <a id=sub1-4><a/>**`4. Logical Operators`**
#
# - More complex decision making can be done using logical operators `and`, `or` and `not`.
#
# - Conditions can be combined using `and` and `or` as shown below:
#   `cond1 and cond2` - returns `True` if both are `True`, otherwise `False`
#   `cond1 or cond2` - returns `True` if one of them is `True`, otherwise `False`
#
# - Strictly speaking, we need not always combine only conditions with `and`/`or`. We can use any valid expression in place of conditions. Hence when used with expressions we may not get `True`/`False`.
#
# - `and` operator evaluates ALL expressions. It returns last expression if all expressions evaluate to `True`. Otherwise, it returns first value that evaluates to `False`.
#
# ```python
# a = 40
# b = 30
# x = 75 and a >= 20 and b < 60 and 35
# # assigns 35 to x
#
# y = -30 and a >= 20 and b < 15 and 35
# # assigns False to y
#
# z = -30 and a >= 20 and 0 and
# ```
# - `or` operator evaluates ALL expressions and returns the first value that evaluates to True. Otherwise, it returns last value that evaluates to False.
#
# ```python
# a = 40
# b = 30
# x = 75 or a >= 20 or 60
# # assigns 75 to x
#
# y = a >= 20 or 75 or 60
# # assigns True to y
#
# z = a < 20 or 0 or 35
# # assign
# ```
#
# - Condition's result can be negated using not.
#
# ```python
# a = 10
# b = 20
# not (a <= b)
# # yields False. Same as a > b
#
# not (a >= b)
# # yields True. Same as
# ```
# - Shortcut for toggling values between 1 and 0:
#
# ```python
# a = int(input('Enter 0 or 1'))
# a = int(not a)
# # set a to 0 if it is 1, and set it to 1 if it is
# ```
# - a = not b does not change value of b.
# -
# If an operator needs only 1 operand it is known as Unary operator, if it needs two, then it is a binary operator.
# not - needs only 1 operand, so unary operat``` or
# +, -, <  ```, >, and, or, etc. - need 2 operands, so binary oper 0 a < bs 35 to z35
# # assigns 0 to z

# %% [markdown]
# ## <a id=sub1-5><a/>**`5. Conditional Expressions`**
# - Python supports one additional decision-making entity called a conditional expression.
# `<expr1>` if `<conditional expression>` else` <expr2>`
# - `<conditional expression>` is evaluated first. If it is True, the expression evaluates to <expr1>. If it is False, the expression evaluates to `<expr2>`.
#
# - Examples of conditional expressions:
# ```python
# age = 15
# status = 'minor' if age < 18 else 'adult'   # sets minor
# sunny = False
# print("Let's go to the", 'beach' if sunny else 'room')
# humidity = 76.8
# setting = 25 if humidity > 75 else 28       # se
# ```
# - Conditional expressions can be nested.
# ```python
# # assigns Prim
# wt = 55
# msg = 'Obese' if wt > 85 else 'Hefty' if wt > 60 else 'Prim'
# ts 25

# %% [markdown]
# ## <a id=sub1-6><a/>**`6. all() and any()`**
#
# Instead of using the and and or logical operators, we can use the built-in functions all() and any() to get the same effect.Their usage is shown in the following program:
#
# ```python
# a, b, c = 10, 20, 30
#
# res = all((a > 5, b > 20, c > 15))
# print(res)   # prints False, as second condition is False
#
# res = any((a > 5, b > 20, c > 15))
# print(res)   # prints True since one of the conditions is
# ```
# - Note that `all()` and `any()` both receive a single parameter of the type string, list, tuple, set, or dictionary.
# - We have passed a tuple of 3 conditions to them. If the argument is a dictionary, it is checked whether the keys are True or not.
# - `any()` function returns `True` if at least one element of its parameter is `True.`
# - `all()` function returns `True` if all elements of its parameter are `True.` True
# sions:it)

# %% [markdown]
# ## <a id=sub1-7><a/>**`7.Receiving Input`**
#
# - The way print() function is used to output values on screen, input() built-in function can be used to receive **input()** values from keyboard.
#
# - **input()** function returns a string, i.e., if 23 is entered it returns '23'.
# So, if we wish to perform arithmetic on the number entered, we need to convert the string into int or float as shown belowl
# ```python
# # Input Examplen
# n = input('Enter your name: ')
# age = int(input('Enter your age: '))
# salary = float(input('Enter your salary: '))
# print(name, age, sarogramslary)se)

# %% [markdown]
# ## <a id=sub1-8><a/>**`8. pass Statement`**
#
# - **pass** statement is intended to do nothing on execution. Hence it is often called a no-op instruction.
# - If we wish that on execution of a statement nothing should happen, we can achieve this using a **pass** statement. Its utility is shown in Problem 5.6.
# - It is often used as a placeholder for unimplemented code in an if loop, function or class. This is not a good use of **pass**. Instead, you should use ... in its place. If you use **pass**, it might make one believe that you actually do not intend to do anything in the if/loop/function/class.

# %% [markdown]
# # <a id=sub1-9><a/>**`P</>Programs`**
#
# ## **`Problem 5.1`**
# While purchasing certain items, a discount of 10% is offered if the quantity purchased is more than 1000. If quantity and price per item are input through the keyboard, write a program to calculate the total expenses.
# ## **`Program`**

# %%
qty = int(input('Enter value of quantity: '))
price = float(input('Enter value of price: '))
if qty > 1000 :
    dis = 10
else :
    dis = 0
totexp = qty * price - qty * price * dis / 100
print('Total expenses = Rs.' + str(totexp))
# Out:
# Enter value of quantity:  12000
# Enter value of price:  23232
# Total expenses = Rs.250905600.0

# %% [markdown]
# ### **`Problem 5.2`**
#
# In a company an employee is paid as under:
# If his basic salary is less than Rs. 1500, then HRA = 10% of basic salary and DA = 90% of basic salary.
# If his salary is either equal to or above Rs. 1500, then HRA = Rs. 500 and DA = 98% of basic salary.
# If the employee's salary is input through the keyboard write a program to find his gross salary.
#
# ### **`Program`**

# %%
bs = int(input('Enter value of bs: '))

if bs > 1000:
    hra = bs * 15 / 100
    da = bs * 95 / 100
    ca = bs * 10 / 100
else:
    hra = bs * 10 / 100
    da = bs * 90 / 100
    ca = bs * 5 / 100

gs = bs + da + hra + ca
print('Gross Salary = Rs. ' + str(gs))
# Out:
# Enter value of bs:  3434
# Gross Salary = Rs. 7554.8

# %% [markdown]
# ## **`TIPS`**
# - if block and else block can contain multiple statement in them, suitably indented.

# %% [markdown]
# ## **`Problem 5.3`**
# Percentage marks obtained by a student are input through the keyboard. The student gets a division as per the following rules:
#
# **Percentage above or equal to 60 - First division**
# **Percentage between 50 and 59 - Second division**
# **Percentage between 40 and 49 - Third division**
# **Percentage less than 40 - Fail**
#
# Write a program to calculate the division obtained by the student.
#
# ### **`Program`**

# %%
per = int(input('Enter value of percentage: '))
if per >= 60 :
    print('First Division')
elif per >= 50 :
    print('Second Division')
elif per >= 40 :
    print('Third Division')
else :
    print('Fail')
# Out:
# Enter value of percentage:  55
# Second Division

# %% [markdown]
# ## **`Problem 5.4`**
#
# A company insures its drivers in the following cases:
# - If the driver is married.
# - If the driver is unmarried, male & above 30 years of age.
# - If the driver is unmarried, female & above 25 years of age.
# - In all other cases, the driver is not insured. If the marital status, sex and age of the driver are the inputs, write a program to determine whether the driver should be insured or not.
#
# ### **`Program`**

# %%
ms = input('Enter marital status: ')
s = input('Enter sex: ')
age = int(input('Enter age: '))

if (ms == 'm') or (ms == 'u' and s == 'm' and age > 30) \
   or (ms == 'u' and s == 'f' and age > 25):
    print('Insured')
else:
    print('Not Insured')
# Out:
# Enter marital status:  454
# Enter sex:  m
# Enter age:  34
# Not Insured

# %% [markdown]
# ## **`Problem 5.5`**
# - uppose there are four flag variables w, x, y, z. Write a program to check in multiple ways whether one of them is true.
# ## **`Program`**

# %%
# Different ways to test multiple flags
w, x, y, z = 0, 1, 0, 1

if w == 1 or x == 1 or y == 1 or z == 1:
    print('True')

if w or x or y or z:
    print('True')

if any((w, x, y, z)):
    print('True')

if 1 in (w,x,y,z):
  print('True')
# Out:
# True
# True
# True
# True

# %% [markdown]
# ## **`Tips`**
#
# - **`any()`** is a built-in function that returns `True` if at least one of the elements of its parameter is `True`.
#
# - We have to pass a string, list, tuple, set or dictionary to `any()`.
#
# - There is another similar function called **`all()`**, which returns `True` if all elements of its parameter are `True`. This function too should be passed a string, list, tuple, set or dictionary.

# %% [markdown]
# ## **`Problem 5.6`**
#
# Given a number `n` we wish to do the following:
#
# - If `n` is positive - print `n * n`, set a flag to true
# - If `n` is negative - print `n * n * n`, set a flag to true
# - If `n` is 0 - do nothing
#
# Is the code given below correct for this logic?
# ```python
# n = int(input('Enter a number: '))
# if n > 0 :
#     flag = True
#     print(n * n)
# elif n < 0 :
#     flag = True
#     print(n * n * n)
# ```
#
# **Answer**
# -
# This is misleading code. At a later date, anybody looking at this code may feel that flag = True should be written outside if and else.
# - **
#
# Better code will be as follo**ws:

# %%
n = int(input('Enter a number: '))
if n > 0 :
    flag = True
    print(n * n)
elif n < 0 :
    flag = True
    print(n * n * n)
else :
    pass # does nothing on execution
# Out:
# Enter a number:  43534
# 1895209156

# %% [markdown]
# # <a id="sub1-10"><a/>**`E-Exercises`**

# %% [markdown]
# ## **`[A] Answer the following questions:`**
#
# ### **`(a) Write conditional expressions for:`**
# - If a < 10 b = 20, else b = 30
# - Print 'Morning' if time < 12, otherwise print 'Afternoon'
# - If marks >= 70, set remarks to True, otherwise False
#
# ## **`program`**

# %% [markdown]
# - **If a < 10 b = 20, else b = 30**

# %%
a = 5
b = 0
if a < 10:
    b= 20
else:
    b=30
print(f"the value of b with method first = {b}")

# another method in sinfle line

b=20 if a<10 else 30
print(f"the value of b with single inline method = {b}")
# Out:
# the value of b with method first = 20
# the value of b with single inline method = 20

# %% [markdown]
# - **Print 'Morning' if time < 12, otherwise print 'Afternoon'**

# %%
time = int(input("Enter the time"))

if time < 12:
   print("morning !")
else:
  print("Afternoon !")

# method 
time = int(input("Enter the time"))
wishes = 'Morning' if time<12 else 'Afternoon'
print(f"{wishes},chirag!")
# Out:
# Enter the time 2
# morning !
# Enter the time 3
# Morning,chirag!

# %% [markdown]
#  - **If marks >= 70, set remarks to True, otherwise False**

# %%
marks =80
remarks=True if marks >=70 else False
print(remarks)
# Out:
# True

# %% [markdown]
# ### **`(b) Rewrite the following code snippet in 1 line:`**

# %%
x = 3
y = 3.0
if x == y :
    print('x and y are equal')
else :
    print('x and y are not equal')
# Out:
# x and y are equal

# %%
x=3
y=3.0
status = "X and y are equal" if x==y else " x and y are not equal"
print(status)
# Out:
# X and y are equal

# %% [markdown]
# ### **(c) pass statement execution:**
# - When a pass statement is executed, nothing happens. It's a null operation that serves as a placeholder where syntax requires a statement but no action is needed.

# %%
## **`[B] Output of the programs:`**

### (a)
```python
i, j, k = 4, -1, 0
w = i or j or k
x = i and j and k
y = i or j and k
z = i and j or k
print(w, x, y, z)

# %% [markdown]
# ```python
# #output
# 4 0 4 -1
#
# #Explanation:
#
# w = i or j or k → First truthy value is 4
#
# x = i and j and k → Evaluates until first falsy value 0
#
# y = i or j and k → Due to precedence: i or (j and k) → 4 or (-1 and 0) → 4 or 0 → 4
#
# z = i and j or k → Due to precedence: (i and j) or k → (4 and -1) or 0 → -1 or 0 → -1

# %% [markdown]
# ### (b)
# ```python
# a = 10
# a = not not a
# print(a)
#
# # Output:
#
# text
# True
#
# # Explanation:
#
# a = 10 (truthy value)
#
# not a → False
#
# not not a → not False → True

# %% [markdown]
# ## (c)
# ```python
# x, y, z = 20, 40, 45
# if x > y and x > z :
#     print('biggest = ' + str(x))
# elif y > x and y > z :
#     print('biggest = ' + str(y))
# elif z > x and z > y :
#     print('biggest = ' + str(z))
#
# #output
# Output: biggest = 45

# %% [markdown]
# ## (d)
# ```python
# num = 30
# k = 100 if num <= 10 else 500
# print(k)
# Output: 500

# %% [markdown]
# ## (e)
# ```python
# a = 10
# b = 60
# if a and b > 20 :
#     print('Hello')
# else :
#     print('Hi')
# Output: Hello

# %% [markdown]
# ## (f)
# ```python
# a = 10
# b = 60
# if a > 20 and b > 20 :
#     print('Hello')
# else :
#     print('Hi')
# Output: Hi

# %% [markdown]
# ## (g)
# ```python
# a = 10
# if a = 30 or 40 or 60 :
#     print('Hello')
# else :
#     print('Hi')
# Output: SyntaxError: invalid syntax (assignment in condition)

# %% [markdown]
# ## (h)
# ```python
# a = 10
# if a == 30 or a == 40 or a == 60 :
#     print('Hello')
# else :
#     print('Hi')
# Output: Hi

# %% [markdown]
# ## (i)
# ```python
# a = 10
# if a in (30, 40, 50) :
#     print('Hello')
# else :
#     print('Hi')
# Output: Hi

# %% [markdown]
# # [C] Errors in the programs:
#
# ## (a)
# ```python
# a = 12.25
# b = 12.52
# if a = b :
#     print('a and b are equal')
#
# # Error: Use of assignment operator = instead of comparison operator == in the if condition.
# # Corrected:
# if a == b :

# %% [markdown]
# ## (b)
# ```python
# if ord('X') < ord('x')
#     print('Unicode value of X is smaller than that of x')
#
# # Error: Missing colon : at the end of the if statement.
# # Corrected:
# # python
# if ord('X') < ord('x'):

# %% [markdown]
# ## (c)
# ```python
# x = 10
# if x >= 2 then
#     print('X')
#
# # Error: Use of then keyword (from other languages) instead of colon : in Python.
# # Corrected:
# # python
# if x >= 2 :

# %% [markdown]
# ## (d)
# ``` python
# x = 10 ; y = 15
# if x % 2 = y % 3
#     print('Carpathians\n')
#
# # Error:
# # Use of assignment operator = instead of comparison operator ==
# # Missing colon : at the end of if statement
# # Corrected:
#
# python
# if x % 2 == y % 3 :

# %% [markdown]
# ## (e)
# ``` python
# x, y = 30, 40
# if x == y :
#     print('x is equal to y')
#     elseif x > y :
#     print('x is greater than y')
#     elseif x < y :
#     print('x is less than y')
#
# # Error: Use of elseif instead of Python's elif keyword.
# # Corrected:
#
# if x == y :
#     print('x is equal to y')
# elif x > y :
#     print('x is greater than y')
# elif x < y :
#     print('x is less than y')

# %% [markdown]
# ## **`[D] Expression evaluations (a=10, b=12, c=0):`**
# ```
# a != 6 and b > 5          # True and True → True
# a == 9 or b < 3           # False or False → False
# not (a < 10)              # not(False) → True
# not (a > 5 and c)         # not(True and False) → not(False) → True
# 5 and c != 8 or not c     # True and True or True → True or True → True```

# %% [markdown]
# ## **`[E] Program Solutions:`**
#
# #### **`(a) Any integer is input through the keyboard. Write a program to find out whether it is an odd number or even number.`**

# %%
num = int(input("Enter an integer: "))
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter an integer:  34
# Even number

# %%
num = int(input("enter number!"))
status ="Even number" if num%2==0 else "odd number"
print(status)
# Out:
# enter number! 2
# Even number

# %% [markdown]
# #### **`(b) Any year is input through the keyboard. Write a program to determine whether the year is a leap year or1 not.`**

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  1986
# Not a leap year

# %% [markdown]
# #### **`(c) If ages of Ram, Shyam and Ajay are input through the keyboard, write a program to determine the youngest of the three.`**

# %%
ram = int(input("Enter Ram's age: "))
shyam = int(input("Enter Shyam's age: "))
ajay = int(input("Enter Ajay's age: "))

if ram < shyam and ram < ajay:
    print("Ram is youngest")
elif shyam < ram and shyam < ajay:
    print("Shyam is youngest")
else:
    print("Ajay is youngest")
# Out:
# Enter Ram's age:  343
# Enter Shyam's age:  45
# Enter Ajay's age:  4
# Ajay is youngest

# %% [markdown]
# #### **`(d) Write a program to check whether a triangle is valid or not, when the three angles of the triangle are entered through the keyboard. A triangle is valid if the sum of all the three angles is 180 degrees`**

# %%
angle1 = float(input("Enter first angle: "))
angle2 = float(input("Enter second angle: "))
angle3 = float(input("Enter third angle: "))

if angle1 + angle2 + angle3 == 180 and angle1 > 0 and angle2 > 0 and angle3 > 0:
    print("Valid triangle")
else:
    print("Invalid triangle")
# Out:
# Enter first angle:  30
# Enter second angle:  60
# Enter third angle:  90
# Valid triangle

# %% [markdown]
# #### **`(e) Write a program to find the absolute value of a number entered through the keyboard.`**

# %%
num = float(input("Enter a number: "))
absolute_value = num if num >= 0 else -num
print(f"Absolute value: {absolute_value}")
# Out:
# Enter a number:  45
# Absolute value: 45.0

# %% [markdown]
# #### **`(f) Given the length and breadth of a rectangle, write a program to check whether the area of the rectangle is greater than its perimeter.`**

# %%
length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth
perimeter = 2 * (length + breadth)

if area > perimeter:
    print("Area is greater than perimeter")
else:
    print("Perimeter is greater than or equal to area")
# Out:
# Enter length:  34
# Enter breadth:  34
# Area is greater than perimeter

# %% [markdown]
# #### **`(g) Given three points (x1, y1), (x2, y2) and (x3, y3), write a program to check if all the three points fall on one straight line.`**

# %%
x1, y1 = map(float, input("Enter point 1 (x1 y1): ").split())
x2, y2 = map(float, input("Enter point 2 (x2 y2): ").split())
x3, y3 = map(float, input("Enter point 3 (x3 y3): ").split())

if (y2 - y1) * (x3 - x2) == (y3 - y2) * (x2 - x1):
    print("Points are collinear (on straight line)")
else:
    print("Points are not collinear")
# Out:
# Enter point 1 (x1 y1):  1 2
# Enter point 2 (x2 y2):  2 3
# Enter point 3 (x3 y3):  3 4
# Points are collinear (on straight line)

# %% [markdown]
# #### ================================= END OF CHAPTER 5 ===============================
